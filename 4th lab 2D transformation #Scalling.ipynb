# %%
#scalling 
import matplotlib.image as img 
import numpy as npy 
import matplotlib.pyplot as plt

m = img.imread("../thes.png"); 

w, h = m.shape[:2]; 

sx = float(input("sx:"))
sy = float(input("sy:"))

xNew = int(w * 2); 
yNew = int(h * 2); 

xScale = xNew/(w-1); 
yScale = yNew/(h-1); 

newImage = npy.zeros([xNew, yNew, 4]); 

for i in range(xNew-1): 
    for j in range(yNew-1): 
        newImage[i + 1, j + 1]= m[1 + int(i / xScale), 1 + int(j / yScale)] 

# Save the image after scaling 
img.imsave('scaled1.png', newImage); 
print(newImage.shape)
plt.imshow(newImage)
# Out:
# sx:2
# sy:3
# (812, 1104, 4)

# %%
import matplotlib.image as img 
import numpy as np
 
m = img.imread("../thes.png"); 

w, h = m.shape[:2]; 
  
xNew = int(w * 0.5); 
yNew = int(h * 0.5); 

xScale = xNew/(w-1); 
yScale = yNew/(h-1); 

newImage = np.zeros([xNew, yNew, 4]); 

for i in range(xNew-1): 
    for j in range(yNew-1): 
        newImage[i + 1, j + 1]= m[1 + int(i / xScale), 1 + int(j / yScale)] 

# Save the image after scaling 
img.imsave('scaled2.png', newImage);

# %%
import matplotlib.image as img 
import numpy as np
 
m = img.imread("../thes.png"); 

w, h = m.shape[:2]; 
  
xNew = int(w * 3); 
yNew = int(h * 3); 

xScale = xNew/(w-1); 
yScale = yNew/(h-1); 

newImage = np.zeros([xNew, yNew, 4]); 

for i in range(xNew-1): 
    for j in range(yNew-1): 
        newImage[i + 1, j + 1]= m[1 + int(i / xScale), 1 + int(j / yScale)] 

# Save the image after scaling 
img.imsave('scaled3.png', newImage);

# %%
import matplotlib.image as img 
import matplotlib.pyplot as plt
import numpy as np
 
m = img.imread("../thes.png"); 

w, h = m.shape[:2]; 
  
xNew = int(w * 3); 
yNew = int(h * 3); 

xScale = xNew/(w-1); 
yScale = yNew/(h-1); 

newImage = np.zeros([xNew, yNew, 4]); 

for i in range(xNew-1): 
    for j in range(yNew-1): 
        newImage[i + 1, j + 1]= m[1 + int(i / xScale), 1 + int(j / yScale)] 

# Save the image after scaling 
#img.imsave('scaled3.png', newImage); 
plt.imshow(m)
plt.show()
plt.imshow(newImage)

# %%
#Sir
import matplotlib.image as img 
import numpy as npy 
 
m = img.imread("../thes.png")

w, h = m.shape[:2]
print(w,h)

sX = 2
sY = 2
  
xNew = int(w * sX)
yNew = int(h * sY)

xScale = xNew/(w-1) 
yScale = yNew/(h-1) 

print(xScale, yScale)

newImage = npy.zeros([xNew, yNew, 4]) 

for i in range(xNew-1): 
    for j in range(yNew-1): 
        newImage[i + 1, j + 1]= m[1 + int(i / xScale), 1 + int(j / yScale)] 

# Save the image after scaling 
img.imsave('scaled5.png', newImage);
# Out:
# 406 552
# 2.004938271604938 2.0036297640653356

# %%
#next rotation task rotation should e below 90 deg
