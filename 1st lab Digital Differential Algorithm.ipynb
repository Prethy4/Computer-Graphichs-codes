# %%
# Assignment: BA

# %%
#input: (x1,y1) to (x2,y2):

x1, y1 = input().split()
x2, y2 = input().split()
# Out:
# 32 35
# 41 41

# %%
# Convert string to int:

x1 = int(x1)
y1 = int(y1)
x2 = int(x2)
y2 = int(y2)

# %%
print(type(x1))
# Out:
# <class 'int'>

# %%
# Slope calculation:

delx = x2 -x1
dely = y2 -y1
m = dely / delx

print(m)
# Out:
# 0.6666666666666666

# %%
# Conditions:

if m>0 and m<=1:
    upx = 1
    upy = m
elif m>=-1 and m<=0:
    upx = -1
    upy = -m
elif m>1:
    upx = 1/m
    upy = 1
elif m<-1:
    upx = -(1/m)
    upy = -1

# %%
print(upx)
print(upy)
# Out:
# 1
# 0.6666666666666666

# %%
x = x1
y = y1

while(1):
    print("(" + str(round(x)) + "," + str(round(y)) +")")
    x = x + upx
    y = y + upy
    if round(x) == x2 and round(y) == y2:
        print("(" + str(round(x)) + "," + str(round(y)) +")")
        break
# Out:
# (32,35)
# (33,36)
# (34,36)
# (35,37)
# (36,38)
# (37,38)
# (38,39)
# (39,40)
# (40,40)
# (41,41)
