# %%
x1 = 0
r = int(input())
y1 =r
# Out:
# 10

# %%
p0 = 1- y1 
print(p0)
# Out:
# -9

# %%
x = x1 
y = y1
while(1):
    if p0>=0:
        x = x + 1
        y = y - 1
        p0 = p0 + (2*x) + 1 - (2*y)
        print("(" + str(x) + "," + str(y) + ")")
    elif p0<0:
        x = x + 1
        p0 = p0+ (2*x)+1
        print("(" + str(x) + "," + str(y) + ")")
    if x == y:
        break
# Out:
# (1,10)
# (2,10)
# (3,10)
# (4,9)
# (5,9)
# (6,8)
# (7,7)
