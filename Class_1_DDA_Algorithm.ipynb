# %%
x1, y1 = input().split()
x2, y2 = input().split()
# Out:
# 2 3
# 6 15

# %%
x1 = int(x1)
y1 = int(y1)
x2 = int(x2)
y2 = int(y2)

# %%
delx = x2 - x1
dely = y2 - y1
m = dely/ delx

# %%
print(m)
# Out:
# 3.0

# %%
if m > 0 and m <= 1:
    upx = 1
    upy = m
elif m>-1 and m<=0:
    upx = -1
    upy = -m
elif m>1:
    upx = 1/m
    upy = 1
elif m<-1:
    upx = -(1/m)
    upy = -1

# %%
print(upx)
print(upy)
# Out:
# 0.3333333333333333
# 1

# %%
x = x1
y = y1

while(x != x2 and y != y2):
    print("(" + str(round(x)) + "," + str(round(y)) + ")")
    x = x + upx
    y = y + upy
print("(" + str(round(x)) + "," + str(round(y)) + ")")
# Out:
# (2,3)
# (2,4)
# (3,5)
# (3,6)
# (3,7)
# (4,8)
# (4,9)
# (4,10)
# (5,11)
# (5,12)
# (5,13)
# (6,14)
# (6,15)

# %%
x = x1
y = y1

while(round(x) != x2 or round(y) != y2):
    print("(" + str(round(x)) + "," + str(round(y)) + ")")
    x = x + upx
    y = y + upy
print("(" + str(round(x)) + "," + str(round(y)) + ")")
# Out:
# (2,3)
# (2,4)
# (3,5)
# (3,6)
# (3,7)
# (4,8)
# (4,9)
# (4,10)
# (5,11)
# (5,12)
# (5,13)
# (6,14)
# (6,15)

# %%
x = x1
y = y1

while(round(x) != x2 and y != y2):
    print("(" + str(round(x)) + "," + str(round(y)) + ")")
    x = x + upx
    y = y + upy
print("(" + str(round(x)) + "," + str(round(y)) + ")")
# Out:
# (2,3)
# (2,4)
# (3,5)
# (3,6)
# (3,7)
# (4,8)
# (4,9)
# (4,10)
# (5,11)
# (5,12)
# (5,13)
# (6,14)

# %%
x1, y1 = input().split()
x2, y2 = input().split()

x1 = int(x1)
y1 = int(y1)
x2 = int(x2)
y2 = int(y2)

delx = x2 - x1
dely = y2 - y1
m = dely / delx

if m > 0 and m <= 1:
    upx = 1
    upy = m
elif m > -1 and m <= 0:
    upx = -1
    upy = -m
elif m > 1:
    upx = 1 / m
    upy = 1
elif m < -1:
    upx = -(1 / m)
    upy = -1

x = x1
y = y1

while (round(x) != x2 and round(y) != y2):  # Corrected loop condition
    print("(" + str(round(x)) + "," + str(round(y)) + ")")
    x = x + upx
    y = y + upy
print("(" + str(round(x)) + "," + str(round(y)) + ")")
# Out:
# 2 3
# 6 15
# (2,3)
# (2,4)
# (3,5)
# (3,6)
# (3,7)
# (4,8)
# (4,9)
# (4,10)
# (5,11)
# (5,12)
# (5,13)
# (6,14)

# %%
x1, y1 = input().split()
x2, y2 = input().split()

x1 = int(x1)
y1 = int(y1)
x2 = int(x2)
y2 = int(y2)

delx = x2 - x1
dely = y2 - y1
m = dely / delx

if m > 0 and m <= 1:
    upx = 1
    upy = m
elif m > -1 and m <= 0:
    upx = -1
    upy = -m
elif m > 1:
    upx = 1 / m
    upy = 1
elif m < -1:
    upx = -(1 / m)
    upy = -1

x = x1
y = y1

while (round(x) != x2 and round(y) != y2):  # Corrected loop condition with "and"
    print("(" + str(round(x)) + "," + str(round(y)) + ")")
    x = x + upx
    y = y + upy
print("(" + str(round(x)) + "," + str(round(y)) + ")")
# Out:
# 2 3
# 6 15
# (2,3)
# (2,4)
# (3,5)
# (3,6)
# (3,7)
# (4,8)
# (4,9)
# (4,10)
# (5,11)
# (5,12)
# (5,13)
# (6,14)
